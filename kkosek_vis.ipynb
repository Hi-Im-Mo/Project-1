# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
filepath = 'output_data/RSV_df_cleaned.csv'
rsvlab_df = pd.read_csv(filepath)

# %%
rsvlab_df.head()
# Out:
#    Unnamed: 0  Year  Month  HHS region  RSV Detections  RSV Tests  \
# 0        2626  2016      1           1              65        430
# 1        2627  2016      1           1              55        453
# 2        2628  2016      1           1              53        441
# 3        2629  2016      1           1              98        480
# 4        2630  2016      1           1              96        520
#
#    % positive tests
# 0         15.116279
# 1         12.141280
# 2         12.018141
# 3         20.416667
# 4         18.461538

# %%
rsvlab_df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'HHS region', 'RSV Detections',
#        'RSV Tests', '% positive tests'],
#       dtype='object')

# %%
del rsvlab_df['Unnamed: 0']

# %%
# Out:
#       Year  Month  HHS region  RSV Detections  RSV Tests  % positive tests
# 0     2016      1           1              65        430         15.116279
# 1     2016      1           1              55        453         12.141280
# 2     2016      1           1              53        441         12.018141
# 3     2016      1           1              98        480         20.416667
# 4     2016      1           1              96        520         18.461538
# ...    ...    ...         ...             ...        ...               ...
# 4588  2020      5           9               2        330          0.606061
# 4589  2020      6           9               0        361          0.000000
# 4590  2020      6           9               0        363          0.000000
# 4591  2020      6           9               1        244          0.409836
# 4592  2020      6           9               0        251          0.000000
#
# [4593 rows x 6 columns]

# %%
# Bugged code

# year index 
year_index = ['2016','2017','2018','2019','2020']
# range of months
month_index = np.arange(1, 13)
# summation lists for appending
sum_rsv_detects_list = []
sum_rsv_tests_list = []
# summation counters
sum_rsv_detects = 0
sum_rsv_tests = 0
# blank counter
counter = 0

# Initialize loop in the year index
for x in year_index:
# Run loop through the dataframe
    for y in rsvlab_df:
# Conditional to sort if were in the same month
        if (rsvlab_df.loc[y, rsvlab_df['Year']] == x) and (rsvlab_df.loc[counter,['Year'] == y]):
# Add the values for 'RSV Detections' and 'RSV Tests' into the counter
            sum_rsv_detects += rsvlab_df.loc[counter, 'RSV Detections']
            sum_rsv_tests += rsvlab_df.loc[counter, 'RSV Tests']

        else:
# If month has changed, append all detects and tests to respective lists
            sum_rsv_detects_list.append(sum_rsv_detects)
            sum_rsv_tests_list.append(sum_rsv_tests)
# Reset counters for loop
            sum_rsv_detects = 0
            sum_rsv_tests = 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 11
#       9 for x in year_index:
#      10     for y in month_index:
# ---> 11         if (rsvlab_df.loc[counter, rsvlab_df['Year']] == x) and (rsvlab_df.loc[counter,['Year'] == y]):
#      12             sum_rsv_detects += rsvlab_df.loc[counter, 'RSV Detections']
#      13             sum_rsv_tests += rsvlab_df.loc[counter, 'RSV Tests']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# ...
